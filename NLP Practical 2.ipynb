# %%
pip install textblob

# %%
import string
from collections import Counter
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob
import nltk
from textblob.sentiments import NaiveBayesAnalyzer, PatternAnalyzer

# %%
text = "Everyone wants to be happy. No one wants to be sad and get pain. But you can't make a rainbow without a little rain. I wish I could make you feel sadness. Then you will know how trerrible it feels. It's very easy to hurt someone and then say sorry but it's realyl difficult to get hurt and then say you're fine. It is hard to forget someone who gave you the best memories ever. Im proud of my heart. Its been played , stabbed, cheated, burned and broken but somehow still works. Sometimes it's not the song that makes you emotional, it's the people and things that come to your mind when you hear it. Every heart has a pain. Only the way of expressing it is difficult. Fools hide it in eyes while the brilliant hide it in their smile. A parent can relax on the sofa when their child asks if they can go play together in the park. Hottest place in hell are reserved for those who in time of great moral crisis , maintain their neutrality. If you truly want to be respected by people you love you must prove to them that you can survive without them. If you are neutral in situations of injustic, you have chosen the side of the oppressor. If can elephant has its foot on the tail of a mouse, and you say that you are neutral, the mouse will not appreciate your neutrality. I booked a 5 night stay at a hotel but I was very angry at the room service. It was utter shit . nothing was happening according to my plan. But being angry dosen't help. You need to be patient with everyone and let them know your needs. You have to keep your behaviour neutral with everyone you talk to so that they don't get offended. neutral and neutrality should be maintained throughout the life while intereacting with anyone you come accross "

# %%
lower_case = text.lower()

# %%
# Removing punctuations
cleaned_text = lower_case.translate(str.maketrans('', '', string.punctuation))

# %%
# splitting text into words
tokenized_words = cleaned_text.split()

tokenized_words
# Out:
# ['everyone',
#  'wants',
#  'to',
#  'be',
#  'happy',
#  'no',
#  'one',
#  'wants',
#  'to',
#  'be',
#  'sad',
#  'and',
#  'get',
#  'pain',
#  'but',
#  'you',
#  'cant',
#  'make',
#  'a',
#  'rainbow',
#  'without',
#  'a',
#  'little',
#  'rain',
#  'i',
#  'wish',
#  'i',
#  'could',
#  'make',
#  'you',
#  'feel',
#  'sadness',
#  'then',
#  'you',
#  'will',
#  'know',
#  'how',
#  'trerrible',
#  'it',
#  'feels',
#  'its',
#  'very',
#  'easy',
#  'to',
#  'hurt',
#  'someone',
#  'and',
#  'then',
#  'say',
#  'sorry',
#  'but',
#  'its',
#  'realyl',
#  'difficult',
#  'to',
#  'get',
#  'hurt',
#  'and',
#  'then',
#  'say',
#  'youre',
#  'fine',
#  'it',
#  'is',
#  'hard',
#  'to',
#  'forget',
#  'someone',
#  'who',
#  'gave',
#  'you',
#  'the',
#  'best',
#  'memories',
#  'ever',
#  'im',
#  'proud',
#  'of',
#  'my',
#  'heart',
#  'its',
#  'been',
#  'played',
#  'stabbed',
#  'cheated',
#  'burned',
#  'and',
#  'broken',
#  'but',
#  'somehow',
# ...

# %%
stop_words = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself",
              "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself",
              "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these",
              "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do",
              "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while",
              "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before",
              "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again",
              "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each",
              "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than",
              "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]

# %%
# Removing stop words from the tokenized words list
final_words = []
for word in tokenized_words:
    if word not in stop_words:
        final_words.append(word)

# %%
# NLP Emotion Algorithm
# 1) Check if the word in the final word list is also present in emotion.txt
#  - open the emotion file
#  - Loop through each line and clear it
#  - Extract the word and emotion using split

# 2) If word is present -> Add the emotion to emotion_list
# 3) Finally count each emotion in the emotion list

# %%
# emotion_list = []
# with open('emotions.txt', 'r') as file:
#     for line in file:
#         clear_line = line.replace("\n", '').replace(",", '').replace("'", '').strip()
#         word, emotion = clear_line.split(':')

#         if word in final_words:
#             emotion_list.append(emotion)



import csv

emotion_list = []

# Open and read the CSV dataset
with open('/content/drive/MyDrive/Colab Notebooks/NLP Practicals/data.csv', 'r', newline='') as csvfile:
    csv_reader = csv.DictReader(csvfile)

    for row in csv_reader:
        word = row['sentiment']
        emotion = row['text']

        if word in final_words:
            emotion_list.append(emotion)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(emotion_list)
w = Counter(emotion_list)
print(w)
# Out:
# ['Director, Global RWE Data Science Analytics - Raritan, NJ, US.\\nJanssen Global Services, LLC., a division of Johnson… https://t.co/klQ5FKX0H8', 'RT @ezekiel_aleke: Master Python and Data Science with these courses, Zero-to-Hero.\\n\\nSome give Certificate after completion.\\n\\nFor absolutel…', 'RT @JhayJahswill: Exploring data science with Helen. @DscEksu @gdgadoekiti \\n#DevFest \\n#DevFest22 \\n#devfestado22 https://t.co/8YMEDloSPr', "@chilagmanuel @PARODYELONHAIR @MansoorOsmar @GergelyOrosz If your degrees aren't in CS and you can't go back to sch… https://t.co/kc7BFoGcCm", 'RT @cxdig: Statistical inference links data and theory in network science https://t.co/QK45xpfQzH https://t.co/YyBU7iupEi', 'RT @bboczeng: 我发现了一个秘密：\\n现在所有的深度学习本质上确实还是data science；实际上还是没有逃脱从data中学习分布，用非线性的高维函数去模拟原分布（generative model）或者把原分布划分成多个区域（discriminative mode…', 'RT @AllForOsint: 4. Applications in Data Science &amp; AI: Cyber Intelligence OSINT - https://t.co/PE5szIraCa', 'RT @trohit007: PYTHON VS 
# ...

# %%
# Plotting the emotions on the graph

fig, ax1 = plt.subplots()
ax1.bar(w.keys(), w.values())
fig.autofmt_xdate()
plt.savefig('graph.png')
plt.show()
# Out:
# <ipython-input-24-a8fa8e53fabf>:6: UserWarning: Glyph 25105 (\N{CJK UNIFIED IDEOGRAPH-6211}) missing from current font.
#   plt.savefig('graph.png')
# <ipython-input-24-a8fa8e53fabf>:6: UserWarning: Glyph 21457 (\N{CJK UNIFIED IDEOGRAPH-53D1}) missing from current font.
#   plt.savefig('graph.png')
# <ipython-input-24-a8fa8e53fabf>:6: UserWarning: Glyph 29616 (\N{CJK UNIFIED IDEOGRAPH-73B0}) missing from current font.
#   plt.savefig('graph.png')
# <ipython-input-24-a8fa8e53fabf>:6: UserWarning: Glyph 20102 (\N{CJK UNIFIED IDEOGRAPH-4E86}) missing from current font.
#   plt.savefig('graph.png')
# <ipython-input-24-a8fa8e53fabf>:6: UserWarning: Glyph 19968 (\N{CJK UNIFIED IDEOGRAPH-4E00}) missing from current font.
#   plt.savefig('graph.png')
# <ipython-input-24-a8fa8e53fabf>:6: UserWarning: Glyph 20010 (\N{CJK UNIFIED IDEOGRAPH-4E2A}) missing from current font.
#   plt.savefig('graph.png')
# ...
