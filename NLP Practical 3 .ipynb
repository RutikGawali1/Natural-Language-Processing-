# %%
text ="""Now is the winter of our discontent
Made glorious summer by this sun of York;
And all the clouds that lour'd upon our house
In the deep bosom of the ocean buried.
Now are our brows bound with victorious wreaths;
Our bruised arms hung up for monuments;
Our stern alarums changed to merry meetings,
Our dreadful marches to delightful measures.
Grim-visaged war hath smooth'd his wrinkled front;
And now, instead of mounting barded steeds
To fright the souls of fearful adversaries,
He capers nimbly in a lady's chamber
To the lascivious pleasing of a lute.
But I, that am not shaped for sportive tricks,
Nor made to court an amorous looking-glass;
I, that am rudely stamp'd, and want love's majesty
To strut before a wanton ambling nymph;
I, that am curtail'd of this fair proportion,"""

# %%
# !pip install -u spacy
# !python -m spacy download en _core_web_sm

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
stopwords = list(STOP_WORDS)

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(text)

# %%
tokens = [token.text for token in doc]
print(tokens)
# Out:
# ['Now', 'is', 'the', 'winter', 'of', 'our', 'discontent', '\n', 'Made', 'glorious', 'summer', 'by', 'this', 'sun', 'of', 'York', ';', '\n', 'And', 'all', 'the', 'clouds', 'that', "lour'd", 'upon', 'our', 'house', '\n', 'In', 'the', 'deep', 'bosom', 'of', 'the', 'ocean', 'buried', '.', '\n', 'Now', 'are', 'our', 'brows', 'bound', 'with', 'victorious', 'wreaths', ';', '\n', 'Our', 'bruised', 'arms', 'hung', 'up', 'for', 'monuments', ';', '\n', 'Our', 'stern', 'alarums', 'changed', 'to', 'merry', 'meetings', ',', '\n', 'Our', 'dreadful', 'marches', 'to', 'delightful', 'measures', '.', '\n', 'Grim', '-', 'visaged', 'war', 'hath', "smooth'd", 'his', 'wrinkled', 'front', ';', '\n', 'And', 'now', ',', 'instead', 'of', 'mounting', 'barded', 'steeds', '\n', 'To', 'fright', 'the', 'souls', 'of', 'fearful', 'adversaries', ',', '\n', 'He', 'capers', 'nimbly', 'in', 'a', 'lady', "'s", 'chamber', '\n', 'To', 'the', 'lascivious', 'pleasing', 'of', 'a', 'lute', '.', '\n', 'But', 'I', ',', 'that', 'am', 'not', 'shaped', 'for', 'sportive', 'tricks', ',', '\n', 'Nor', 'made', 'to', 'court', 'an', 'amorous', 'looking', '-', 'glass', ';', '\n', 'I', ',', 'that', 'am', 'rudely', "stamp'd", ',', 'and', 'want', 'love', "'s", 'majesty', '\n', 'To', 'strut', 'before', 'a', 'wanton', 'ambling', 'nymph', ';', '\n', 'I', ',', 'that', 'am', "curtail'd", 'of', 'this', 'fair', 'proportion', ',']

# %%
punctuation = punctuation + '\n'
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~\n'

# %%
word_frequencies = {}
for word in doc:
  if word.text.lower()not in stopwords:
    if word.text.lower() not in punctuation:
      if word.text not in word_frequencies.keys():
        word_frequencies[word.text] = 1
      else:
          word_frequencies += 1

# %%
print(word_frequencies)
# Out:
# {'winter': 1, 'discontent': 1, 'glorious': 1, 'summer': 1, 'sun': 1, 'York': 1, 'clouds': 1, "lour'd": 1, 'house': 1, 'deep': 1, 'bosom': 1, 'ocean': 1, 'buried': 1, 'brows': 1, 'bound': 1, 'victorious': 1, 'wreaths': 1, 'bruised': 1, 'arms': 1, 'hung': 1, 'monuments': 1, 'stern': 1, 'alarums': 1, 'changed': 1, 'merry': 1, 'meetings': 1, 'dreadful': 1, 'marches': 1, 'delightful': 1, 'measures': 1, 'Grim': 1, 'visaged': 1, 'war': 1, 'hath': 1, "smooth'd": 1, 'wrinkled': 1, 'instead': 1, 'mounting': 1, 'barded': 1, 'steeds': 1, 'fright': 1, 'souls': 1, 'fearful': 1, 'adversaries': 1, 'capers': 1, 'nimbly': 1, 'lady': 1, 'chamber': 1, 'lascivious': 1, 'pleasing': 1, 'lute': 1, 'shaped': 1, 'sportive': 1, 'tricks': 1, 'court': 1, 'amorous': 1, 'looking': 1, 'glass': 1, 'rudely': 1, "stamp'd": 1, 'want': 1, 'love': 1, 'majesty': 1, 'strut': 1, 'wanton': 1, 'ambling': 1, 'nymph': 1, "curtail'd": 1, 'fair': 1, 'proportion': 1}

# %%
max_frequencies = max(word_frequencies.values())

# %%
max_frequencies
# Out:
# 1

# %%
for word in word_frequencies.keys():
  word_frequencies[word] = word_frequencies[word]/max_frequencies

# %%
print(word_frequencies)
# Out:
# {'winter': 1.0, 'discontent': 1.0, 'glorious': 1.0, 'summer': 1.0, 'sun': 1.0, 'York': 1.0, 'clouds': 1.0, "lour'd": 1.0, 'house': 1.0, 'deep': 1.0, 'bosom': 1.0, 'ocean': 1.0, 'buried': 1.0, 'brows': 1.0, 'bound': 1.0, 'victorious': 1.0, 'wreaths': 1.0, 'bruised': 1.0, 'arms': 1.0, 'hung': 1.0, 'monuments': 1.0, 'stern': 1.0, 'alarums': 1.0, 'changed': 1.0, 'merry': 1.0, 'meetings': 1.0, 'dreadful': 1.0, 'marches': 1.0, 'delightful': 1.0, 'measures': 1.0, 'Grim': 1.0, 'visaged': 1.0, 'war': 1.0, 'hath': 1.0, "smooth'd": 1.0, 'wrinkled': 1.0, 'instead': 1.0, 'mounting': 1.0, 'barded': 1.0, 'steeds': 1.0, 'fright': 1.0, 'souls': 1.0, 'fearful': 1.0, 'adversaries': 1.0, 'capers': 1.0, 'nimbly': 1.0, 'lady': 1.0, 'chamber': 1.0, 'lascivious': 1.0, 'pleasing': 1.0, 'lute': 1.0, 'shaped': 1.0, 'sportive': 1.0, 'tricks': 1.0, 'court': 1.0, 'amorous': 1.0, 'looking': 1.0, 'glass': 1.0, 'rudely': 1.0, "stamp'd": 1.0, 'want': 1.0, 'love': 1.0, 'majesty': 1.0, 'strut': 1.0, 'wanton': 1.0, 'ambling': 1.0, 'nymph': 1.0, "curtail'd": 1.0, 'fair': 1.0, 'proportion': 1.0}

# %%
sentence_tokens = [sent for sent in doc.sents]
print(sentence_tokens)
# Out:
# [Now is the winter of our discontent
# Made glorious summer by this sun of York;
# And all the clouds that lour'd upon our house
# In the deep bosom of the ocean buried.
# , Now are our brows bound with victorious wreaths;
# Our bruised arms hung up for monuments;
# Our stern alarums changed to merry meetings,
# Our dreadful marches to delightful measures.
# , Grim-visaged war hath smooth'd his wrinkled front;
# And now, instead of mounting barded steeds
# To fright the souls of fearful adversaries,
# He capers nimbly in a lady's chamber
# To the lascivious pleasing of a lute.
# , But I, that am not shaped for sportive tricks,
# Nor made to court an amorous looking-glass;
# I, that am rudely stamp'd, and want love's majesty
# To strut before a wanton ambling nymph;
# I, that am curtail'd of this fair proportion,]

# %%
sentence_scores = {}
for sent in sentence_tokens:
  for word in sent:
    if word.text.lower() in word_frequencies.keys():
      if sent not in sentence_scores.keys():
        sentence_scores[sent] = word_frequencies[word.text.lower()]
      else:
        sentence_scores[sent] += word_frequencies[word.text.lower()]

# %%
sentence_scores
# Out:
# {Now is the winter of our discontent
#  Made glorious summer by this sun of York;
#  And all the clouds that lour'd upon our house
#  In the deep bosom of the ocean buried.: 12.0,
#  Now are our brows bound with victorious wreaths;
#  Our bruised arms hung up for monuments;
#  Our stern alarums changed to merry meetings,
#  Our dreadful marches to delightful measures.: 17.0,
#  Grim-visaged war hath smooth'd his wrinkled front;
#  And now, instead of mounting barded steeds
#  To fright the souls of fearful adversaries,
#  He capers nimbly in a lady's chamber
#  To the lascivious pleasing of a lute.: 20.0,
#  But I, that am not shaped for sportive tricks,
#  Nor made to court an amorous looking-glass;
#  I, that am rudely stamp'd, and want love's majesty
#  To strut before a wanton ambling nymph;
#  I, that am curtail'd of this fair proportion,: 19.0}

# %%
from heapq import nlargest

# %%
select_length = int(len(sentence_tokens)*0.3)
select_length
# Out:
# 1

# %%
summary = nlargest(select_length, sentence_scores, key = sentence_scores.get)

# %%
summary
# Out:
# [Grim-visaged war hath smooth'd his wrinkled front;
#  And now, instead of mounting barded steeds
#  To fright the souls of fearful adversaries,
#  He capers nimbly in a lady's chamber
#  To the lascivious pleasing of a lute.]

# %%
final_summary = [word.text for word in summary]

# %%
summary = ' '.join(final_summary)

# %%
print(text)
# Out:
# Now is the winter of our discontent
# Made glorious summer by this sun of York;
# And all the clouds that lour'd upon our house
# In the deep bosom of the ocean buried.
# Now are our brows bound with victorious wreaths;
# Our bruised arms hung up for monuments;
# Our stern alarums changed to merry meetings,
# Our dreadful marches to delightful measures.
# Grim-visaged war hath smooth'd his wrinkled front;
# And now, instead of mounting barded steeds
# To fright the souls of fearful adversaries,
# He capers nimbly in a lady's chamber
# To the lascivious pleasing of a lute.
# But I, that am not shaped for sportive tricks,
# Nor made to court an amorous looking-glass;
# I, that am rudely stamp'd, and want love's majesty
# To strut before a wanton ambling nymph;
# I, that am curtail'd of this fair proportion,

# %%
print(summary)
# Out:
# Grim-visaged war hath smooth'd his wrinkled front;
# And now, instead of mounting barded steeds
# To fright the souls of fearful adversaries,
# He capers nimbly in a lady's chamber
# To the lascivious pleasing of a lute.

# %%
len(text)
# Out:
# 782

# %%
len(summary)
# Out:
# 213
